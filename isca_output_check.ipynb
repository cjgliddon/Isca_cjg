# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from os.path import join

# %%
rootdir = '/home/cgliddon/orcd/scratch/isca/data/frierson_default_6hr_restart'
ds_1_f = join(rootdir, 'run0020', 'atmos_6_hourly.nc')
ds_1 = xr.open_dataset(ds_1_f)

# %%
fig, ax = plt.subplots(figsize=(10, 5), layout='tight')
cm = ax.contourf(ds_1.lon, ds_1.lat, ds_1.isel(time=0).ps)
fig.colorbar(cm)

# %%
ds_1
# Out:
# <xarray.Dataset>
# Dimensions:        (lon: 256, lonb: 257, lat: 128, latb: 129, time: 1,
#                     phalf: 31, pfull: 30)
# Coordinates:
#   * lon            (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#   * lonb           (lonb) float64 -0.7031 0.7031 2.109 ... 356.5 357.9 359.3
#   * lat            (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#   * latb           (latb) float64 -90.0 -88.28 -86.87 ... 86.87 88.28 90.0
#   * time           (time) object 0001-01-06 00:00:00
#   * phalf          (phalf) float64 0.0 0.06412 0.1981 ... 693.0 832.5 1e+03
#   * pfull          (pfull) float64 0.02359 0.125 0.3422 ... 634.1 761.7 915.0
# Data variables:
#     ps             (time, lat, lon) float32 ...
#     bk             (phalf) float32 ...
#     pk             (phalf) float32 ...
#     precipitation  (time, lat, lon) float32 ...
#     t_surf         (time, lat, lon) float32 ...
#     sphum          (time, pfull, lat, lon) float32 ...
# ...
